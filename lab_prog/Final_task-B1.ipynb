# %% [markdown]
# # Load Dataset IPL_Matches_2008_2022.csv

# %%
import pandas as pd

# %% [markdown]
# # Standardization of Team Names by Replacing Old Franchise Names with Updated Names
# Delhi Daredevils → Delhi Capitals
#
# Kings XI Punjab → Punjab Kings
#
# Rising Pune Supergiants → Rising Pune Supergiant

# %% [markdown]
# # Task 1: Top Winning Team per Season

# %% [markdown]
# # Task 2: Player of Match Diversity per Winning Team

# %% [markdown]
# ### TASK-3 : Ranking Teams by Match Wins Based on Toss Decision (Descending Order)

# %% [markdown]
# # Task-4:Analysis of Top five Venues with Highest Match Frequency and Their Dominant Winning Teams (Descending Order)

# %% [markdown]
# # Task-5: Season-wise IPL Points Table Generation
